# %% [markdown]
# <a href="https://colab.research.google.com/github/gomyk/NNStudy/blob/moonwon/%5BRL%5D%5BDDPG%5D%5BMW%5D%20Pendulum-v0%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import modules

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !apt-get install x11-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# x11-utils is already the newest version (7.7+3build1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.

# %%
import gym
from gym.wrappers import Monitor
import math
import random
import copy
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
from PIL import Image
from typing import Dict, List, Tuple

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

import base64

from IPython.display import HTML

from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

from google.colab import output

display = Display(visible=0, size=(400,600),)
display.start()
env = gym.make("Pendulum-v0")

#env = gym.wrappers.Monitor(gym.make("CartPole-v1"), "video", force=True, video_callable=lambda c:c%100 ==0)

# GPU를 사용할 경우
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ##Replay Memory

# %%
class ReplayMemory:
    """A simple numpy replay buffer."""

    def __init__(self, action_dim:int , obs_dim: int, size: int, batch_size: int):
        """Initializate."""
        self.obs_buf = np.zeros([size, obs_dim], dtype=np.float32)
        self.next_obs_buf = np.zeros([size, obs_dim], dtype=np.float32)
        self.acts_buf = np.zeros([size, action_dim], dtype=np.float32)
        self.rews_buf = np.zeros([size], dtype=np.float32)
        self.done_buf = np.zeros([size], dtype=np.float32)
        self.max_size, self.batch_size = size, batch_size
        self.ptr, self.size, = 0, 0

    def store(
        self,
        obs: np.ndarray,
        act: np.ndarray, 
        rew: float, 
        next_obs: np.ndarray, 
        done: bool,
    ):
        """Store the transition in buffer."""
        self.obs_buf[self.ptr] = obs
        self.next_obs_buf[self.ptr] = next_obs
        self.acts_buf[self.ptr] = act
        self.rews_buf[self.ptr] = rew
        self.done_buf[self.ptr] = done
        self.ptr = (self.ptr + 1) % self.max_size
        self.size = min(self.size + 1, self.max_size)

    def sample_batch(self) -> Dict[str, np.ndarray]:
        """Randomly sample a batch of experiences from memory."""
        idxs = np.random.choice(self.size, size=self.batch_size, replace=False)
        return dict(obs=self.obs_buf[idxs],
                    next_obs=self.next_obs_buf[idxs],
                    acts=self.acts_buf[idxs],
                    rews=self.rews_buf[idxs],
                    done=self.done_buf[idxs])

    def __len__(self) -> int:
        return self.size

# %% [markdown]
# ##Define Noise Generator

# %%
class OUNoise:
    """Ornstein-Uhlenbeck process.
    Taken from Udacity deep-reinforcement-learning github repository:
    https://github.com/udacity/deep-reinforcement-learning/blob/master/
    ddpg-pendulum/ddpg_agent.py
    """

    def __init__(
        self, 
        size: int, 
        mu: float = 0.0, 
        theta: float = 0.15, 
        sigma: float = 0.2,
    ):
        """Initialize parameters and noise process."""
        self.state = np.float64(0.0)
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.reset()

    def reset(self):
        """Reset the internal state (= noise) to mean (mu)."""
        self.state = copy.copy(self.mu)

    def sample(self) -> np.ndarray:
        """Update internal state and return it as a noise sample."""
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.array(
            [random.random() for _ in range(len(x))]
        )
        self.state = x + dx
        return self.state

# %% [markdown]
# ##Actor Network

# %%
HIDDEN_SIZE = 128
class Actor(nn.Module):

    def __init__(self, obs_size, outputs, init_w: float = 3e-3,):
        super(Actor, self).__init__()
        self.linear = nn.Linear(obs_size, HIDDEN_SIZE)
        self.linear2 = nn.Linear(HIDDEN_SIZE, HIDDEN_SIZE)
        self.linear3 = nn.Linear(HIDDEN_SIZE, HIDDEN_SIZE)
        self.head = nn.Linear(HIDDEN_SIZE, outputs)

        self.head.weight.data.uniform_(-init_w, init_w)
        self.head.bias.data.uniform_(-init_w, init_w)

    def forward(self, state: torch.Tensor) -> torch.Tensor:
        x = F.relu(self.linear(state))
        x = F.relu(self.linear2(x))
        x = F.relu(self.linear3(x))
        return self.head(x).tanh()

# %% [markdown]
# ##Critic Network

# %%
class Critic(nn.Module):

    def __init__(self, obs_size, action_size, init_w: float = 3e-3,):
        super(Critic, self).__init__()
        self.linear = nn.Linear(obs_size + action_size, HIDDEN_SIZE)
        self.linear2 = nn.Linear(HIDDEN_SIZE, HIDDEN_SIZE)
        self.linear3 = nn.Linear(HIDDEN_SIZE, HIDDEN_SIZE)
        self.head = nn.Linear(HIDDEN_SIZE, 1)

        self.head.weight.data.uniform_(-init_w, init_w)
        self.head.bias.data.uniform_(-init_w, init_w)

    def forward(self, state: torch.Tensor, action: torch.Tensor) -> torch.Tensor:
        """Forward method implementation."""
        x = torch.cat((state, action), dim=-1)
        x = F.relu(self.linear(x))
        x = F.relu(self.linear2(x))
        x = F.relu(self.linear3(x))
        return self.head(x)

# %% [markdown]
# ###Environment Snapshot

# %%
env.reset()
plt.figure()
plt.imshow(env.render(mode='rgb_array'))
plt.title('Example extracted screen')
plt.show()

# %% [markdown]
# ##Prepare to learning

# %%
BATCH_SIZE = 256
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 2000
TARGET_UPDATE = 10
ACTOR_LR = 0.001
CRITIC_LR = 0.001
MEMORY_SIZE = 10000
EPISODE_SIZE = 100
TAU = 0.005
ou_noise_theta = 1.0
ou_noise_sigma = 0.1

RECORD_INTERVAL = 10

# gym 행동 공간에서 행동의 숫자를 얻습니다.
#n_actions = env.action_space.n
n_actions = 1
n_obvs = 3

actor = Actor(n_obvs, n_actions).to(device)
actor.eval()
actor_target = Actor(n_obvs, n_actions).to(device)
actor_target.load_state_dict(actor.state_dict())
actor_target.eval()

critic = Critic(n_obvs, n_actions).to(device)
critic.eval()
critic_target = Critic(n_obvs, n_actions).to(device)
critic_target.load_state_dict(critic.state_dict())
critic_target.eval()

actor_optimizer = optim.Adam(actor.parameters(), lr=ACTOR_LR)
critic_optimizer = optim.Adam(critic.parameters(), lr=CRITIC_LR)
memory = ReplayMemory(n_actions,n_obvs,MEMORY_SIZE,BATCH_SIZE)

noise = OUNoise(
            n_actions,
            theta=ou_noise_theta,
            sigma=ou_noise_sigma,
        )

steps_done = 0

def select_action(state):
    global steps_done
    sample = random.random()
    steps_done += 1
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    if sample < eps_threshold:
            #selected_action = [np.random.uniform(0,1),np.random.uniform(0,1),np.random.uniform(0,1)]
            selected_action = [np.random.uniform(-1,1)]
    else:
        selected_action = actor(
             torch.FloatTensor(state).to(device)
         ).detach().cpu().numpy()
    _noise = noise.sample()
    for action in selected_action:
      action = np.clip(action + _noise, -1.0, 1.0)
    return selected_action
episode_durations = []


def plot_durations():
    plt.figure(2)
    plt.clf()
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # 100개의 에피소드 평균을 가져 와서 도표 그리기
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

# %%
def target_soft_update():
        #Soft-update: target = tau*local + (1-tau)*target
        tau = TAU
        
        for t_param, l_param in zip(
            actor_target.parameters(), actor.parameters()
        ):
            t_param.data.copy_(tau * l_param.data + (1.0 - tau) * t_param.data)
            
        for t_param, l_param in zip(
            critic_target.parameters(), critic.parameters()
        ):
            t_param.data.copy_(tau * l_param.data + (1.0 - tau) * t_param.data)

# %% [markdown]
# ##Optimizer

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return -1 , -1
    samples = memory.sample_batch()
    state = torch.FloatTensor(samples["obs"]).to(device)
    next_state = torch.FloatTensor(samples["next_obs"]).to(device)
    action = torch.FloatTensor(samples["acts"]).to(device)
    reward = torch.FloatTensor(samples["rews"].reshape(-1, 1)).to(device)
    done = torch.FloatTensor(samples["done"].reshape(-1, 1)).to(device)
    
    masks = 1 - done
    next_action = actor_target(next_state)
    next_value = critic_target(next_state, next_action)
    curr_return = reward + GAMMA * next_value * masks

    # train critic
    values = critic(state, action)
    critic_loss = F.smooth_l1_loss(values, curr_return)
    critic_optimizer.zero_grad()
    critic_loss.backward()
    critic_optimizer.step()     
    # train actor
    loss = critic(state, actor(state))
    actor_loss = -loss.mean()
        
    actor_optimizer.zero_grad()
    actor_loss.backward()
    actor_optimizer.step()
        
    # target update
    target_soft_update()

    return actor_loss.data, critic_loss.data

# %% [markdown]
# ##Train

# %%
frames = []
for i_episode in range(EPISODE_SIZE):
    # 환경과 상태 초기화
    obv = env.reset()
    total_actor_loss = 0
    total_critic_loss = 0
    global steps_done
    top_reward = -1
    total_reward = 0
    total_action_count = [0,0,0]
    for t in count():
        if i_episode % RECORD_INTERVAL == 0:
          frames.append(env.render(mode="rgb_array"))
        # 행동 선택과 수행
        action = select_action(obv)
        next_obv, reward, done, _ = env.step(action*2)
        index  = 1
        if action[0] > 0 :
          index = 2
        elif action[0] < 0:
          index = 0
        total_action_count[index] += 1
        #reward  = obv[0]
        if reward > top_reward:
          top_reward = reward
        total_reward += reward
        # 메모리에 변이 저장
        assert obv is not None
        memory.store(obv, action, reward, next_obv, done)

        # 다음 상태로 이동
        obv = next_obv

        # 최적화 한단계 수행(목표 네트워크에서)
        actor_loss, critic_loss = optimize_model()
        total_actor_loss += actor_loss
        total_critic_loss += critic_loss
        if done:
            E = eps_threshold = EPS_END + (EPS_START - EPS_END) * \
            math.exp(-1. * steps_done / EPS_DECAY)
            episode_durations.append(t + 1)
            print('%d episode , %d step , %.2f Actor Loss, %.2f Critic Loss,  %.2f Threshold , %.2f Top reward, %.2f Avg reward'\
                  %(i_episode,t+1,total_actor_loss/(t+1), total_critic_loss/(t+1) ,E, top_reward, total_reward/(t+1)))
            print(total_action_count)
            plot_durations()
            total_actor_loss = 0
            total_critic_loss = 0
            top_reward = 0
            total_reward = 0
            total_action_count = [0,0,0]
            break
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        actor_target.load_state_dict(actor.state_dict())
        critic_target.load_state_dict(critic.state_dict())
print('Complete')
env.render()
env.close()
plt.show()
# Out:
# 0 episode , 200 step , -1.00 Actor Loss, -1.00 Critic Loss,  0.82 Threshold , -0.59 Top reward, -5.34 Avg reward
# [106, 0, 94]
# 1 episode , 200 step , 3.51 Actor Loss, 0.51 Critic Loss,  0.75 Threshold , -1.00 Top reward, -6.67 Avg reward
# [111, 0, 89]
# 2 episode , 200 step , 8.97 Actor Loss, 0.05 Critic Loss,  0.68 Threshold , -1.00 Top reward, -9.00 Avg reward
# [78, 0, 122]
# 3 episode , 200 step , 14.38 Actor Loss, 0.03 Critic Loss,  0.62 Threshold , -1.00 Top reward, -8.79 Avg reward
# [77, 0, 123]
# 4 episode , 200 step , 20.01 Actor Loss, 0.06 Critic Loss,  0.57 Threshold , -0.02 Top reward, -6.31 Avg reward
# [101, 0, 99]
# 5 episode , 200 step , 26.44 Actor Loss, 0.10 Critic Loss,  0.52 Threshold , -1.00 Top reward, -8.51 Avg reward
# [118, 0, 82]
# 6 episode , 200 step , 32.67 Actor Loss, 0.15 Critic Loss,  0.47 Threshold , -0.54 Top reward, -6.61 Avg reward
# [102, 0, 98]
# 7 episode , 200 step , 38.87 Actor Loss, 0.19 Critic Loss,  0.43 Threshold , -0.85 Top reward, -6.78 Avg reward
# [101, 0, 99]
# 8 episode , 200 step , 44.95 Actor Loss, 0.23 Critic Loss,  0.40 Threshold , -1.00 Top reward, -6.75 Avg reward
# [105, 0, 95]
# 9 episode , 200 step , 50.53 Actor Loss, 0.28 Critic Loss,  0.36 Threshold , -1.00 Top reward, -6.17 Avg reward
# [95, 0, 105]
# 10 episode , 200 step , 54.78 Actor Loss, 0.33 Critic Loss,  0.33 Threshold , -0.00 Top reward, -2.01 Avg reward
# [92, 0, 108]
# 11 episode , 200 step , 62.75 Actor Loss, 0.74 Critic Loss,  0.31 Threshold , -0.00 Top reward, -3.27 Avg reward
# [99, 0, 101]
# 12 episode , 200 step , 64.85 Actor Loss, 0.43 Critic Loss,  0.28 Threshold , -0.00 Top reward, -3.16 Avg reward
# [103, 0, 97]
# 13 episode , 200 step , 66.96 Actor Loss, 0.45 Critic Loss,  0.26 Threshold , -0.00 Top reward, -1.98 Avg reward
# [76, 0, 124]
# 14 episode , 200 step , 67.28 Actor Loss, 0.45 Critic Loss,  0.24 Threshold , -0.00 Top reward, -1.26 Avg reward
# [82, 0, 118]
# 15 episode , 200 step , 67.72 Actor Loss, 0.49 Critic Loss,  0.22 Threshold , -0.00 Top reward, -0.64 Avg reward
# [106, 0, 94]
# 16 episode , 200 step , 66.84 Actor Loss, 0.45 Critic Loss,  0.21 Threshold , -0.00 Top reward, -0.00 Avg reward
# [121, 0, 79]
# 17 episode , 200 step , 67.05 Actor Loss, 0.49 Critic Loss,  0.19 Threshold , -0.00 Top reward, -1.25 Avg reward
# [110, 0, 90]
# 18 episode , 200 step , 66.68 Actor Loss, 0.49 Critic Loss,  0.18 Threshold , -0.00 Top reward, -0.62 Avg reward
# [117, 0, 83]
# 19 episode , 200 step , 66.33 Actor Loss, 0.59 Critic Loss,  0.17 Threshold , -0.00 Top reward, -1.32 Avg reward
# [142, 0, 58]
# 20 episode , 200 step , 67.67 Actor Loss, 0.73 Critic Loss,  0.15 Threshold , -0.03 Top reward, -6.88 Avg reward
# [36, 0, 164]
# 21 episode , 200 step , 70.82 Actor Loss, 1.07 Critic Loss,  0.14 Threshold , -0.00 Top reward, -0.64 Avg reward
# [31, 0, 169]
# 22 episode , 200 step , 71.33 Actor Loss, 0.86 Critic Loss,  0.14 Threshold , -0.01 Top reward, -5.29 Avg reward
# [54, 0, 146]
# 23 episode , 200 step , 71.44 Actor Loss, 0.89 Critic Loss,  0.13 Threshold , -0.01 Top reward, -0.02 Avg reward
# [10, 0, 190]
# 24 episode , 200 step , 71.51 Actor Loss, 0.82 Critic Loss,  0.12 Threshold , -0.01 Top reward, -0.65 Avg reward
# [18, 0, 182]
# 25 episode , 200 step , 70.06 Actor Loss, 0.80 Critic Loss,  0.11 Threshold , -0.01 Top reward, -0.59 Avg reward
# [12, 0, 188]
# 26 episode , 200 step , 69.81 Actor Loss, 0.87 Critic Loss,  0.11 Threshold , -0.00 Top reward, -1.52 Avg reward
# [29, 0, 171]
# 27 episode , 200 step , 69.05 Actor Loss, 0.86 Critic Loss,  0.10 Threshold , -0.00 Top reward, -0.01 Avg reward
# [17, 0, 183]
# 28 episode , 200 step , 67.54 Actor Loss, 0.90 Critic Loss,  0.10 Threshold , -0.00 Top reward, -0.60 Avg reward
# [58, 0, 142]
# 29 episode , 200 step , 67.32 Actor Loss, 0.88 Critic Loss,  0.09 Threshold , -0.00 Top reward, -0.63 Avg reward
# [68, 0, 132]
# 30 episode , 200 step , 65.71 Actor Loss, 0.93 Critic Loss,  0.09 Threshold , -0.00 Top reward, -0.58 Avg reward
# [83, 0, 117]
# 31 episode , 200 step , 66.00 Actor Loss, 0.97 Critic Loss,  0.08 Threshold , -0.00 Top reward, -0.61 Avg reward
# [106, 0, 94]
# 32 episode , 200 step , 65.90 Actor Loss, 0.97 Critic Loss,  0.08 Threshold , -0.00 Top reward, -1.20 Avg reward
# [102, 0, 98]
# 33 episode , 200 step , 65.59 Actor Loss, 0.87 Critic Loss,  0.08 Threshold , -0.00 Top reward, -0.61 Avg reward
# [96, 0, 104]
# 34 episode , 200 step , 65.66 Actor Loss, 0.88 Critic Loss,  0.08 Threshold , -0.00 Top reward, -1.79 Avg reward
# [92, 0, 108]
# 35 episode , 200 step , 64.54 Actor Loss, 0.91 Critic Loss,  0.07 Threshold , -0.00 Top reward, -0.59 Avg reward
# [95, 0, 105]
# 36 episode , 200 step , 63.34 Actor Loss, 0.92 Critic Loss,  0.07 Threshold , -0.00 Top reward, -0.61 Avg reward
# [103, 0, 97]
# 37 episode , 200 step , 64.14 Actor Loss, 0.92 Critic Loss,  0.07 Threshold , -0.00 Top reward, -1.71 Avg reward
# [104, 0, 96]
# 38 episode , 200 step , 61.88 Actor Loss, 0.91 Critic Loss,  0.07 Threshold , -0.00 Top reward, -0.61 Avg reward
# [110, 0, 90]
# 39 episode , 200 step , 62.63 Actor Loss, 0.83 Critic Loss,  0.07 Threshold , -0.00 Top reward, -1.16 Avg reward
# [95, 0, 105]
# 40 episode , 200 step , 60.36 Actor Loss, 0.88 Critic Loss,  0.06 Threshold , -0.00 Top reward, -0.59 Avg reward
# [90, 0, 110]
# 41 episode , 200 step , 59.61 Actor Loss, 0.92 Critic Loss,  0.06 Threshold , -0.00 Top reward, -0.63 Avg reward
# [93, 0, 107]
# 42 episode , 200 step , 59.14 Actor Loss, 0.88 Critic Loss,  0.06 Threshold , -0.00 Top reward, -0.01 Avg reward
# [99, 0, 101]
# 43 episode , 200 step , 59.25 Actor Loss, 0.92 Critic Loss,  0.06 Threshold , -0.00 Top reward, -1.15 Avg reward
# [99, 0, 101]
# 44 episode , 200 step , 57.82 Actor Loss, 0.79 Critic Loss,  0.06 Threshold , -0.00 Top reward, -0.61 Avg reward
# [101, 0, 99]
# 45 episode , 200 step , 56.61 Actor Loss, 0.78 Critic Loss,  0.06 Threshold , -0.00 Top reward, -0.61 Avg reward
# [91, 0, 109]
# 46 episode , 200 step , 56.55 Actor Loss, 0.75 Critic Loss,  0.06 Threshold , -0.00 Top reward, -0.61 Avg reward
# [100, 0, 100]
# 47 episode , 200 step , 54.91 Actor Loss, 0.79 Critic Loss,  0.06 Threshold , -0.00 Top reward, -0.62 Avg reward
# [104, 0, 96]
# 48 episode , 200 step , 54.28 Actor Loss, 0.71 Critic Loss,  0.06 Threshold , -0.00 Top reward, -0.62 Avg reward
# [98, 0, 102]
# 49 episode , 200 step , 53.29 Actor Loss, 0.74 Critic Loss,  0.06 Threshold , -0.00 Top reward, -0.61 Avg reward
# [96, 0, 104]
# 50 episode , 200 step , 52.07 Actor Loss, 0.74 Critic Loss,  0.06 Threshold , -0.00 Top reward, -0.58 Avg reward
# [110, 0, 90]
# 51 episode , 200 step , 50.62 Actor Loss, 0.66 Critic Loss,  0.05 Threshold , -0.00 Top reward, -1.22 Avg reward
# [103, 0, 97]
# 52 episode , 200 step , 46.50 Actor Loss, 0.70 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.58 Avg reward
# [112, 0, 88]
# 53 episode , 200 step , 40.35 Actor Loss, 0.63 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.61 Avg reward
# [99, 0, 101]
# 54 episode , 200 step , 37.14 Actor Loss, 0.55 Critic Loss,  0.05 Threshold , -0.00 Top reward, -1.17 Avg reward
# [100, 0, 100]
# 55 episode , 200 step , 31.79 Actor Loss, 0.49 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.59 Avg reward
# [104, 0, 96]
# 56 episode , 200 step , 28.02 Actor Loss, 0.42 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.62 Avg reward
# [92, 0, 108]
# 57 episode , 200 step , 24.16 Actor Loss, 0.38 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.60 Avg reward
# [104, 0, 96]
# 58 episode , 200 step , 20.43 Actor Loss, 0.32 Critic Loss,  0.05 Threshold , -0.00 Top reward, -1.46 Avg reward
# [105, 0, 95]
# 59 episode , 200 step , 17.52 Actor Loss, 0.28 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.59 Avg reward
# [89, 0, 111]
# 60 episode , 200 step , 15.92 Actor Loss, 0.23 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.60 Avg reward
# [93, 0, 107]
# 61 episode , 200 step , 15.59 Actor Loss, 0.25 Critic Loss,  0.05 Threshold , -0.00 Top reward, -1.78 Avg reward
# [106, 0, 94]
# 62 episode , 200 step , 14.77 Actor Loss, 0.22 Critic Loss,  0.05 Threshold , -0.00 Top reward, -1.20 Avg reward
# [96, 0, 104]
# 63 episode , 200 step , 13.78 Actor Loss, 0.18 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.59 Avg reward
# [78, 0, 122]
# 64 episode , 200 step , 13.72 Actor Loss, 0.16 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.61 Avg reward
# [91, 0, 109]
# 65 episode , 200 step , 13.43 Actor Loss, 0.18 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.00 Avg reward
# [101, 0, 99]
# 66 episode , 200 step , 13.45 Actor Loss, 0.23 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.62 Avg reward
# [109, 0, 91]
# 67 episode , 200 step , 13.46 Actor Loss, 0.19 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.60 Avg reward
# [96, 0, 104]
# 68 episode , 200 step , 13.47 Actor Loss, 0.17 Critic Loss,  0.05 Threshold , -0.00 Top reward, -1.16 Avg reward
# [100, 0, 100]
# 69 episode , 200 step , 13.74 Actor Loss, 0.19 Critic Loss,  0.05 Threshold , -0.00 Top reward, -1.25 Avg reward
# [101, 0, 99]
# 70 episode , 200 step , 12.70 Actor Loss, 0.15 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.62 Avg reward
# [97, 0, 103]
# 71 episode , 200 step , 11.63 Actor Loss, 0.13 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.01 Avg reward
# [101, 0, 99]
# 72 episode , 200 step , 10.95 Actor Loss, 0.12 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.61 Avg reward
# [92, 0, 108]
# 73 episode , 200 step , 10.71 Actor Loss, 0.11 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.59 Avg reward
# [83, 0, 117]
# 74 episode , 200 step , 10.61 Actor Loss, 0.10 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.61 Avg reward
# [108, 0, 92]
# 75 episode , 200 step , 10.55 Actor Loss, 0.10 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.61 Avg reward
# [91, 0, 109]
# 76 episode , 200 step , 10.62 Actor Loss, 0.11 Critic Loss,  0.05 Threshold , -0.00 Top reward, -1.10 Avg reward
# [95, 0, 105]
# 77 episode , 200 step , 10.65 Actor Loss, 0.10 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.58 Avg reward
# [91, 0, 109]
# 78 episode , 200 step , 11.00 Actor Loss, 0.11 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.63 Avg reward
# [60, 0, 140]
# 79 episode , 200 step , 10.61 Actor Loss, 0.12 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.57 Avg reward
# [11, 0, 189]
# 80 episode , 200 step , 10.45 Actor Loss, 0.11 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.61 Avg reward
# [38, 0, 162]
# 81 episode , 200 step , 10.52 Actor Loss, 0.11 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.59 Avg reward
# [37, 0, 163]
# 82 episode , 200 step , 10.29 Actor Loss, 0.11 Critic Loss,  0.05 Threshold , -0.00 Top reward, -1.12 Avg reward
# [80, 0, 120]
# 83 episode , 200 step , 10.51 Actor Loss, 0.12 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.58 Avg reward
# [38, 0, 162]
# 84 episode , 200 step , 9.82 Actor Loss, 0.11 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.62 Avg reward
# [69, 0, 131]
# 85 episode , 200 step , 10.00 Actor Loss, 0.10 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.67 Avg reward
# [58, 0, 142]
# 86 episode , 200 step , 10.09 Actor Loss, 0.12 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.61 Avg reward
# [142, 0, 58]
# 87 episode , 200 step , 9.37 Actor Loss, 0.08 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.60 Avg reward
# [122, 0, 78]
# 88 episode , 200 step , 9.87 Actor Loss, 0.09 Critic Loss,  0.05 Threshold , -0.00 Top reward, -1.16 Avg reward
# [119, 0, 81]
# 89 episode , 200 step , 9.38 Actor Loss, 0.09 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.58 Avg reward
# [116, 0, 84]
# 90 episode , 200 step , 9.79 Actor Loss, 0.09 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.63 Avg reward
# [116, 0, 84]
# 91 episode , 200 step , 9.64 Actor Loss, 0.08 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.59 Avg reward
# [110, 0, 90]
# 92 episode , 200 step , 10.13 Actor Loss, 0.08 Critic Loss,  0.05 Threshold , -0.00 Top reward, -1.83 Avg reward
# [93, 0, 107]
# 93 episode , 200 step , 10.23 Actor Loss, 0.09 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.60 Avg reward
# [124, 0, 76]
# 94 episode , 200 step , 10.35 Actor Loss, 0.09 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.61 Avg reward
# [99, 0, 101]
# 95 episode , 200 step , 10.19 Actor Loss, 0.08 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.00 Avg reward
# [82, 0, 118]
# 96 episode , 200 step , 10.12 Actor Loss, 0.08 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.62 Avg reward
# [81, 0, 119]
# 97 episode , 200 step , 10.03 Actor Loss, 0.08 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.60 Avg reward
# [107, 0, 93]
# 98 episode , 200 step , 10.11 Actor Loss, 0.08 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.65 Avg reward
# [86, 0, 114]
# 99 episode , 200 step , 10.29 Actor Loss, 0.07 Critic Loss,  0.05 Threshold , -0.00 Top reward, -0.61 Avg reward
# [72, 0, 128]
# Complete

# %% [markdown]
# ## Rendering

# %%
# !pip install JSAnimation
from matplotlib import animation, rc
from JSAnimation.IPython_display import display_animation
from IPython.display import display

import os
import glob
import io
# Out:
# Requirement already satisfied: JSAnimation in /usr/local/lib/python3.6/dist-packages (0.1)

# %%
def show_video():
  mp4list = glob.glob('./*.mp4')
  if len(mp4list) > 0:
    print(mp4list)
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")

# %%
# Imports specifically so we can render outputs in Colab.
fig = plt.figure()
def display_frames_as_gif(frame):
    """Displays a list of frames as a gif, with controls."""
    patch = plt.imshow(frame[0].astype(int))
    def animate(i):
        patch.set_data(frame[i].astype(int))

    anim = animation.FuncAnimation(
        fig, animate, frames=len(frames), interval=30, blit=False
    )
    #display(display_animation(anim, default_mode='loop'))
    # Set up formatting for the movie files
    display(HTML(data=anim.to_html5_video()))
    #FFwriter = animation.FFMpegWriter()
    #anim.save('basic_animation.mp4', writer = FFwriter)
    #show_video()
# display 
display_frames_as_gif(frames)
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
