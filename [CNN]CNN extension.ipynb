# %%
import torch
import torchvision
import torchvision.transforms as transforms

import numpy as np

torch.manual_seed(2019)

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))])

# %%
train_data = torchvision.datasets.CIFAR100('./data/', train=True, transform= trans, download=True)
test_data = torchvision.datasets.CIFAR100('./data/', train=False, transform= trans, download=True)
# Out:
# 0it [00:00, ?it/s]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 169009152it [00:09, 17579323.55it/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data/
# Files already downloaded and verified

# %%
batch_size = 64

conv_channel_1 = 128
conv_channel_2 = 256
conv_channel_3 = 256
conv_channel_4 = 512
conv_channel_5 = 512

hidden1_size = 1024
out_size = 100
epoch = 50

# %%
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size,shuffle=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import time

# %%
loss = nn.CrossEntropyLoss()

# %%
import torch.optim as optim
from torch.autograd import Variable

def fit(epoch, data_loader, model, opt, phase):
    if phase=='train':
        volatile = False
        model.train()
    else:
        volatile = True
        model.eval()       
        
    learning_loss = 0.
    learning_correct = 0
    
    for i, (inputs, labels) in enumerate(data_loader):
        if phase == 'train':
            opt.zero_grad()
            
        inputs = Variable(inputs, volatile).cuda()
        labels = Variable(labels).cuda()
        outputs = model(inputs)
        
        loss_value = loss(outputs, labels)
        learning_loss += loss_value.item() * inputs.shape[0]
        
        if phase == 'train':
            loss_value.backward()
            opt.step()
        
        _, preds = torch.max(outputs.data, 1)
        learning_correct += (preds == labels).sum().item()
        
    epoch_loss = learning_loss /len(data_loader.dataset)
    epoch_correct = learning_correct / len(data_loader.dataset) * 100.
    
    print(f'epoch = {epoch} -> {phase:{5}} / loss = {epoch_loss:{8}.{3}}, correct = {epoch_correct:{8}.{4}}%')

# %%
class commonLinear(nn.Module):
    def __init__(self, nin):
        super(commonLinear, self).__init__()
        self.fc=nn.Sequential(
            nn.Linear(nin, hidden1_size),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(hidden1_size, out_size),
            nn.ReLU()
        )
        
    def forward(self,x):
        x=self.fc(x)
        return F.log_softmax(x, dim=1)

# %%
class normalCNN(nn.Module):
    def __init__(self):
        super(normalCNN,self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(3, conv_channel_1, 3, padding=1),
            nn.BatchNorm2d(conv_channel_1),
            nn.ReLU(),
            nn.Conv2d(conv_channel_1, conv_channel_2, 3, padding=1),
            nn.BatchNorm2d(conv_channel_2),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(conv_channel_2, conv_channel_3, 3, padding=1),
            nn.BatchNorm2d(conv_channel_3),
            nn.ReLU(),
            nn.Conv2d(conv_channel_3, conv_channel_4, 3, padding=1),
            nn.BatchNorm2d(conv_channel_4),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(conv_channel_4, conv_channel_5, 3, padding=1),
            nn.BatchNorm2d(conv_channel_5),
            nn.ReLU(),
            nn.AvgPool2d(2,2)
        )
        
        self.fc = commonLinear(conv_channel_5*4*4)
        
    def forward(self,x):
        x=self.conv(x)
        x=x.view(-1,conv_channel_5*4*4)
        x=self.fc(x)
        return x

# %%
cnn1 = normalCNN().cuda()
#opt1 = optim.Adadelta(cnn1.parameters(), rho=0.95)
opt1 = optim.SGD(cnn1.parameters(), lr=0.01, momentum=0.9)
print(cnn1)
# Out:
# normalCNN(
#   (conv): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (15): ReLU()
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU()
#     (19): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (20): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU()
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (25): ReLU()
#     (26): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   )
#   (fc): commonLinear(
#     (fc): Sequential(
#       (0): Linear(in_features=8192, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.5, inplace=False)
#       (3): Linear(in_features=1024, out_features=100, bias=True)
#       (4): ReLU()
#     )
#   )
# )

# %%
for ep in range(epoch):
    t= time.time()
    fit(ep, train_loader, cnn1, opt1, 'train')
    fit(ep, test_loader, cnn1, opt1, 'eval')
    print('%.4f'%(time.time()-t))
    print()
# Out:
# epoch = 0 -> train / loss =     3.81, correct =    12.72%
# epoch = 0 -> eval  / loss =     3.22, correct =    22.36%
# 60.9932
#
# epoch = 1 -> train / loss =     2.95, correct =    26.18%
# epoch = 1 -> eval  / loss =     2.52, correct =    34.62%
# 60.7587
#
# epoch = 2 -> train / loss =     2.47, correct =    35.39%
# epoch = 2 -> eval  / loss =      2.2, correct =    41.43%
# 60.6141
#
# epoch = 3 -> train / loss =     2.14, correct =    42.56%
# epoch = 3 -> eval  / loss =     2.12, correct =    43.65%
# 60.5708
#
# epoch = 4 -> train / loss =     1.87, correct =    48.51%
# epoch = 4 -> eval  / loss =      1.8, correct =    51.11%
# 60.5755
#
# epoch = 5 -> train / loss =     1.66, correct =    53.72%
# epoch = 5 -> eval  / loss =     1.67, correct =    53.77%
# 60.5526
#
# epoch = 6 -> train / loss =     1.46, correct =    58.28%
# epoch = 6 -> eval  / loss =     1.69, correct =    54.24%
# 60.5279
#
# epoch = 7 -> train / loss =     1.29, correct =    62.32%
# epoch = 7 -> eval  / loss =     1.66, correct =    55.26%
# 60.4979
#
# epoch = 8 -> train / loss =     1.15, correct =    66.05%
# epoch = 8 -> eval  / loss =     1.53, correct =    58.05%
# 60.5082
#
# epoch = 9 -> train / loss =    0.997, correct =    70.29%
# epoch = 9 -> eval  / loss =     1.45, correct =    60.29%
# 60.5875
#
# epoch = 10 -> train / loss =    0.873, correct =    73.29%
# epoch = 10 -> eval  / loss =     1.49, correct =    60.52%
# 60.5464
#
# epoch = 11 -> train / loss =    0.755, correct =    76.47%
# epoch = 11 -> eval  / loss =     1.42, correct =    62.35%
# 60.5193
#
# epoch = 12 -> train / loss =    0.647, correct =    79.95%
# epoch = 12 -> eval  / loss =     1.51, correct =    62.54%
# 60.4830
#
# epoch = 13 -> train / loss =    0.557, correct =    82.29%
# epoch = 13 -> eval  / loss =     1.45, correct =    63.32%
# 60.5394
#
# epoch = 14 -> train / loss =    0.482, correct =    84.68%
# epoch = 14 -> eval  / loss =     1.51, correct =    62.39%
# 60.5080
#
# epoch = 15 -> train / loss =    0.396, correct =    87.13%
# epoch = 15 -> eval  / loss =     1.46, correct =    63.79%
# 60.4881
#
# epoch = 16 -> train / loss =    0.335, correct =    89.15%
# epoch = 16 -> eval  / loss =      1.5, correct =    63.21%
# 60.4220
#
# epoch = 17 -> train / loss =    0.283, correct =    90.82%
# epoch = 17 -> eval  / loss =     1.64, correct =    62.51%
# 60.4432
#
# epoch = 18 -> train / loss =    0.239, correct =    92.25%
# epoch = 18 -> eval  / loss =     1.63, correct =    64.28%
# 60.4872
#
# epoch = 19 -> train / loss =    0.203, correct =     93.5%
# epoch = 19 -> eval  / loss =     1.61, correct =    65.11%
# 60.5238
#
# epoch = 20 -> train / loss =    0.181, correct =    94.13%
# epoch = 20 -> eval  / loss =     1.57, correct =    65.62%
# 60.4375
#
# epoch = 21 -> train / loss =    0.151, correct =     95.1%
# epoch = 21 -> eval  / loss =     1.65, correct =     65.0%
# 60.4565
#
# epoch = 22 -> train / loss =    0.128, correct =    95.89%
# epoch = 22 -> eval  / loss =     1.63, correct =     66.0%
# 60.4304
#
# epoch = 23 -> train / loss =    0.118, correct =    96.29%
# epoch = 23 -> eval  / loss =     1.75, correct =    64.15%
# 60.4899
#
# epoch = 24 -> train / loss =    0.104, correct =     96.7%
# epoch = 24 -> eval  / loss =     1.66, correct =    66.08%
# 60.4748
#
# epoch = 25 -> train / loss =   0.0959, correct =    96.98%
# epoch = 25 -> eval  / loss =     1.74, correct =    65.31%
# 60.4405
#
# epoch = 26 -> train / loss =   0.0831, correct =    97.41%
# epoch = 26 -> eval  / loss =     1.72, correct =    65.52%
# 60.4056
#
# epoch = 27 -> train / loss =    0.075, correct =    97.65%
# epoch = 27 -> eval  / loss =     1.76, correct =    66.52%
# 60.3929
#
# epoch = 28 -> train / loss =   0.0739, correct =    97.68%
# epoch = 28 -> eval  / loss =     1.75, correct =    66.16%
# 60.4222
#
# epoch = 29 -> train / loss =   0.0626, correct =    98.07%
# epoch = 29 -> eval  / loss =     1.87, correct =    64.99%
# 60.4748
#
# epoch = 30 -> train / loss =   0.0591, correct =    98.16%
# epoch = 30 -> eval  / loss =      1.8, correct =     66.4%
# 60.4319
#
# epoch = 31 -> train / loss =   0.0487, correct =    98.49%
# epoch = 31 -> eval  / loss =     1.87, correct =    65.76%
# 60.4338
#
# epoch = 32 -> train / loss =   0.0551, correct =     98.3%
# epoch = 32 -> eval  / loss =      1.9, correct =    66.12%
# 60.4118
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-6cad5e66893a> in <module>()
#       1 for ep in range(epoch):
#       2     t= time.time()
# ----> 3     fit(ep, train_loader, cnn1, opt1, 'train')
#       4     fit(ep, test_loader, cnn1, opt1, 'eval')
#       5     print('%.4f'%(time.time()-t))
#
# <ipython-input-9-92bfdd7a48f8> in fit(epoch, data_loader, model, opt, phase)
#      29
#      30         _, preds = torch.max(outputs.data, 1)
# ---> 31         learning_correct += (preds == labels).sum().item()
#      32
#      33     epoch_loss = learning_loss /len(data_loader.dataset)
#
# KeyboardInterrupt:

# %%
class depthwiseCNN(nn.Module):
    def __init__(self,nin,nout):
        super(depthwiseCNN,self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(nin,nin,3,groups=nin, padding=1),
            nn.BatchNorm2d(nin),
            nn.ReLU(),
            nn.Conv2d(nin,nout,1),
            nn.BatchNorm2d(nout),
            nn.ReLU()
        )

    def forward(self,x):
        return self.model(x)
        
class separableCNN(nn.Module):
    def __init__(self):
        super(separableCNN,self).__init__()
        self.conv = nn.Sequential(
            depthwiseCNN(3,conv_channel_1),
            depthwiseCNN(conv_channel_1,conv_channel_2),
            nn.MaxPool2d(2,2),
            depthwiseCNN(conv_channel_2,conv_channel_3),
            depthwiseCNN(conv_channel_3,conv_channel_4),
            nn.MaxPool2d(2,2),
            depthwiseCNN(conv_channel_4,conv_channel_5),
            nn.AvgPool2d(2,2)
        )
        
        self.fc = commonLinear(conv_channel_5*4*4)
        
    def forward(self,x):
        x=self.conv(x)
        x=x.view(-1,conv_channel_5*4*4)
        x=self.fc(x)
        return x

# %%
cnn2 = separableCNN().cuda()
#opt2 = optim.Adadelta(cnn2.parameters(), rho=0.95)
opt2 = optim.SGD(cnn2.parameters(), lr=0.01, momentum=0.9)
print(cnn2)
# Out:
# separableCNN(
#   (conv): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): depthwiseCNN(
#       (model): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): depthwiseCNN(
#       (model): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): depthwiseCNN(
#       (model): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#       )
#     )
#     (14): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   )
#   (fc): commonLinear(
#     (fc): Sequential(
#       (0): Linear(in_features=8192, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.5, inplace=False)
#       (3): Linear(in_features=1024, out_features=100, bias=True)
#       (4): ReLU()
#     )
#   )
# )

# %%
for ep in range(epoch):
    t=time.time()
    fit(ep, train_loader, cnn2, opt2, 'train')
    fit(ep, test_loader, cnn2, opt2, 'eval')
    print('%.4f'%(time.time()-t))
    print()
# Out:
# epoch = 0 -> train / loss =     3.75, correct =    13.73%
# epoch = 0 -> eval  / loss =     2.95, correct =    25.72%
# 27.8952
#
# epoch = 1 -> train / loss =     2.84, correct =     28.1%
# epoch = 1 -> eval  / loss =     2.44, correct =    36.87%
# 27.8950
#
# epoch = 2 -> train / loss =      2.4, correct =    37.34%
# epoch = 2 -> eval  / loss =     2.17, correct =    43.15%
# 27.7103
#
# epoch = 3 -> train / loss =     2.09, correct =    43.72%
# epoch = 3 -> eval  / loss =     1.89, correct =    48.59%
# 28.1700
#
# epoch = 4 -> train / loss =     1.84, correct =    49.12%
# epoch = 4 -> eval  / loss =     1.72, correct =     52.4%
# 28.5500
#
# epoch = 5 -> train / loss =     1.62, correct =     54.3%
# epoch = 5 -> eval  / loss =     1.71, correct =    53.61%
# 28.2421
#
# epoch = 6 -> train / loss =     1.43, correct =    58.74%
# epoch = 6 -> eval  / loss =      1.7, correct =    54.07%
# 28.1134
#
# epoch = 7 -> train / loss =     1.25, correct =    63.01%
# epoch = 7 -> eval  / loss =     1.57, correct =    56.16%
# 28.1180
#
# epoch = 8 -> train / loss =     1.09, correct =    67.26%
# epoch = 8 -> eval  / loss =     1.55, correct =    58.19%
# 28.0294
#
# epoch = 9 -> train / loss =    0.948, correct =    71.08%
# epoch = 9 -> eval  / loss =     1.56, correct =    57.91%
# 28.1103
#
# epoch = 10 -> train / loss =    0.816, correct =    74.65%
# epoch = 10 -> eval  / loss =     1.56, correct =    59.45%
# 28.1641
#
# epoch = 11 -> train / loss =    0.695, correct =    78.11%
# epoch = 11 -> eval  / loss =     1.72, correct =    57.77%
# 28.2081
#
# epoch = 12 -> train / loss =    0.606, correct =    80.52%
# epoch = 12 -> eval  / loss =     1.59, correct =    58.56%
# 28.0534
#
# epoch = 13 -> train / loss =    0.525, correct =    83.13%
# epoch = 13 -> eval  / loss =     1.62, correct =    60.31%
# 27.9476
#
# epoch = 14 -> train / loss =    0.443, correct =    85.66%
# epoch = 14 -> eval  / loss =     1.75, correct =     59.6%
# 27.8906
#
# epoch = 15 -> train / loss =    0.382, correct =    87.57%
# epoch = 15 -> eval  / loss =     1.81, correct =     58.5%
# 27.9819
#
# epoch = 16 -> train / loss =     0.33, correct =    89.24%
# epoch = 16 -> eval  / loss =      1.8, correct =    59.25%
# 27.8537
#
# epoch = 17 -> train / loss =    0.283, correct =    90.81%
# epoch = 17 -> eval  / loss =      1.9, correct =    59.77%
# 27.8239
#
# epoch = 18 -> train / loss =     0.25, correct =    91.91%
# epoch = 18 -> eval  / loss =     2.02, correct =    58.77%
# 27.6382
#
# epoch = 19 -> train / loss =    0.227, correct =    92.73%
# epoch = 19 -> eval  / loss =      1.8, correct =    60.83%
# 27.7267
#
# epoch = 20 -> train / loss =    0.185, correct =    94.03%
# epoch = 20 -> eval  / loss =     1.94, correct =     59.9%
# 27.5226
#
# epoch = 21 -> train / loss =    0.169, correct =    94.54%
# epoch = 21 -> eval  / loss =     1.98, correct =    60.73%
# 27.6856
#
# epoch = 22 -> train / loss =    0.152, correct =    95.09%
# epoch = 22 -> eval  / loss =     1.96, correct =    60.75%
# 27.6648
#
# epoch = 23 -> train / loss =    0.134, correct =     95.8%
# epoch = 23 -> eval  / loss =     2.02, correct =    61.26%
# 27.7695
#
# epoch = 24 -> train / loss =     0.12, correct =    96.04%
# epoch = 24 -> eval  / loss =     2.05, correct =    60.26%
# 27.7082
#
# epoch = 25 -> train / loss =    0.116, correct =    96.36%
# epoch = 25 -> eval  / loss =     2.11, correct =    59.35%
# 27.9265
#
# epoch = 26 -> train / loss =    0.106, correct =    96.56%
# epoch = 26 -> eval  / loss =     2.04, correct =    60.62%
# 27.7241
#
# epoch = 27 -> train / loss =   0.0979, correct =    96.95%
# epoch = 27 -> eval  / loss =     2.17, correct =    60.38%
# 27.7394
#
# epoch = 28 -> train / loss =   0.0798, correct =    97.46%
# epoch = 28 -> eval  / loss =     2.08, correct =    61.34%
# 27.7800
#
# epoch = 29 -> train / loss =   0.0737, correct =    97.62%
# epoch = 29 -> eval  / loss =     2.27, correct =    60.72%
# 27.6541
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-eb65ec1863de> in <module>()
#       1 for ep in range(epoch):
#       2     t=time.time()
# ----> 3     fit(ep, train_loader, cnn2, opt2, 'train')
#       4     fit(ep, test_loader, cnn2, opt2, 'eval')
#       5     print('%.4f'%(time.time()-t))
#
# <ipython-input-9-92bfdd7a48f8> in fit(epoch, data_loader, model, opt, phase)
#      19         inputs = Variable(inputs, volatile).cuda()
#      20         labels = Variable(labels).cuda()
# ---> 21         outputs = model(inputs)
#      22
#      23         loss_value = loss(outputs, labels)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-33-d28da97810a4> in forward(self, x)
#      43         x=self.conv(x)
#      44         x=x.view(-1,conv_channel_6*4*4)
# ---> 45         x=self.fc(x)
#      46         return x
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-25-02e905427867> in forward(self, x)
#      11
#      12     def forward(self,x):
# ---> 13         x=self.fc(x)
#      14         return F.log_softmax(x, dim=1)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/activation.py in forward(self, input)
#      92
#      93     def forward(self, input):
# ---> 94         return F.relu(input, inplace=self.inplace)
#      95
#      96     def extra_repr(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in relu(input, inplace)
#     912         result = torch.relu_(input)
#     913     else:
# --> 914         result = torch.relu(input)
#     915     return result
#     916
#
# KeyboardInterrupt:

# %%
class inception(nn.Module):
    def __init__(self, nin, nout):
        super(inception,self).__init__()
        self.model1x1 = nn.Sequential(
            nn.Conv2d(nin, int(nout/4), 1)
        )
        self.model3x3 = nn.Sequential(
            nn.Conv2d(nin,int(nout/8),1),
            nn.Conv2d(int(nout/8),int(nout/4),3, padding=1)
        )
        self.model5x5 = nn.Sequential(
            nn.Conv2d(nin,int(nout/16),1),
            nn.Conv2d(int(nout/16),int(nout/8),3,padding=1),
            nn.Conv2d(int(nout/8),int(nout/4),3,padding=1)
        )
        self.modelmax = nn.Sequential(
            nn.MaxPool2d(3, stride=1, padding=1),
            nn.Conv2d(nin,int(nout/4),1)
        )
        
    def forward(self, x):
        part1x1=self.model1x1(x)
        part3x3=self.model3x3(x)
        part5x5=self.model5x5(x)
        partmax=self.modelmax(x)
        outputs= [part1x1, part3x3, part5x5, partmax]
        return torch.cat(outputs,1)
    
class inceptionCNN(nn.Module):
    def __init__(self):
        super(inceptionCNN, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(3,conv_channel_1, 3, padding=1),
            nn.BatchNorm2d(conv_channel_1),
            nn.ReLU(),
            nn.Conv2d(conv_channel_2, conv_channel_2, 3, padding=1),
            nn.BatchNorm2d(conv_channel_1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(conv_channel_1, conv_channel_2, 3, padding=1),
            nn.BatchNorm2d(conv_channel_2),
            nn.ReLU(),
            inception(conv_channel_2, conv_channel_3),
            nn.BatchNorm2d(conv_channel_3),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            inception(conv_channel_3, conv_channel_4),
            nn.BatchNorm2d(conv_channel_4),
            nn.ReLU(),
            inception(conv_channel_4, conv_channel_5),
            nn.BatchNorm2d(conv_channel_5),
            nn.ReLU(),
            nn.AvgPool2d(2,2)
        )
        
        self.fc=commonLinear(conv_channel_5*4*4)
    
    def forward(self,x):
        x=self.conv(x)
        x=x.view(-1, conv_channel_5*4*4)
        x=self.fc(x)
        return x

# %%
cnn3 = inceptionCNN().cuda()
#opt3 = optim.Adadelta(cnn3.parameters(), rho=0.95)
opt3 = optim.SGD(cnn3.parameters(), lr=0.01, momentum=0.9)
print(cnn3)
# Out:
# inceptionCNN(
#   (conv): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): inception(
#       (model1x1): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (model3x3): Sequential(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (model5x5): Sequential(
#         (0): Conv2d(64, 8, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (modelmax): Sequential(
#         (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#         (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): inception(
#       (model1x1): Sequential(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (model3x3): Sequential(
#         (0): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (model5x5): Sequential(
#         (0): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (modelmax): Sequential(
#         (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (15): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU()
#     (17): inception(
#       (model1x1): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (model3x3): Sequential(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (model5x5): Sequential(
#         (0): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (modelmax): Sequential(
#         (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#         (1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU()
#     (20): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   )
#   (fc): commonLinear(
#     (fc): Sequential(
#       (0): Linear(in_features=4096, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.5, inplace=False)
#       (3): Linear(in_features=1024, out_features=100, bias=True)
#       (4): ReLU()
#     )
#   )
# )

# %%
for ep in range(epoch):
    t=time.time()
    fit(ep, train_loader, cnn3, opt3, 'train')
    fit(ep, test_loader, cnn3, opt3, 'eval')
    print('%.4f'%(time.time()-t))
    print()
# Out:
# epoch = 0 -> train / loss =     3.59, correct =    15.88%
# epoch = 0 -> eval  / loss =     2.75, correct =    29.42%
# 21.8676
#
# epoch = 1 -> train / loss =     2.66, correct =    31.74%
# epoch = 1 -> eval  / loss =     2.39, correct =    37.41%
# 21.8273
#
# epoch = 2 -> train / loss =     2.25, correct =    40.24%
# epoch = 2 -> eval  / loss =     2.06, correct =    45.76%
# 21.7285
#
# epoch = 3 -> train / loss =     1.97, correct =    46.49%
# epoch = 3 -> eval  / loss =     1.91, correct =    49.35%
# 21.8206
#
# epoch = 4 -> train / loss =     1.77, correct =    51.09%
# epoch = 4 -> eval  / loss =     1.84, correct =    50.37%
# 21.7078
#
# epoch = 5 -> train / loss =     1.59, correct =    55.27%
# epoch = 5 -> eval  / loss =      1.7, correct =    53.31%
# 21.8872
#
# epoch = 6 -> train / loss =     1.45, correct =    58.77%
# epoch = 6 -> eval  / loss =     1.66, correct =    54.76%
# 21.6896
#
# epoch = 7 -> train / loss =     1.31, correct =    62.28%
# epoch = 7 -> eval  / loss =     1.58, correct =    56.67%
# 21.7583
#
# epoch = 8 -> train / loss =     1.19, correct =    65.08%
# epoch = 8 -> eval  / loss =     1.57, correct =    56.84%
# 21.7776
#
# epoch = 9 -> train / loss =     1.08, correct =    68.05%
# epoch = 9 -> eval  / loss =     1.58, correct =    56.51%
# 21.5589
#
# epoch = 10 -> train / loss =    0.978, correct =    70.82%
# epoch = 10 -> eval  / loss =      1.6, correct =    57.12%
# 21.7229
#
# epoch = 11 -> train / loss =    0.896, correct =    73.05%
# epoch = 11 -> eval  / loss =     1.56, correct =    58.22%
# 21.8022
#
# epoch = 12 -> train / loss =    0.797, correct =    75.76%
# epoch = 12 -> eval  / loss =     1.58, correct =    58.15%
# 21.5938
#
# epoch = 13 -> train / loss =    0.728, correct =    77.48%
# epoch = 13 -> eval  / loss =     1.58, correct =    58.91%
# 21.5665
#
# epoch = 14 -> train / loss =    0.656, correct =    79.53%
# epoch = 14 -> eval  / loss =     1.54, correct =    60.49%
# 21.7759
#
# epoch = 15 -> train / loss =    0.586, correct =    81.55%
# epoch = 15 -> eval  / loss =     1.58, correct =    60.37%
# 21.5688
#
# epoch = 16 -> train / loss =    0.525, correct =     83.3%
# epoch = 16 -> eval  / loss =     1.57, correct =    59.85%
# 21.6658
#
# epoch = 17 -> train / loss =    0.456, correct =    85.56%
# epoch = 17 -> eval  / loss =     1.61, correct =    60.61%
# 21.4821
#
# epoch = 18 -> train / loss =    0.423, correct =    86.66%
# epoch = 18 -> eval  / loss =     1.63, correct =    60.39%
# 21.6017
#
# epoch = 19 -> train / loss =    0.379, correct =    87.92%
# epoch = 19 -> eval  / loss =     1.66, correct =    60.26%
# 21.7045
#
# epoch = 20 -> train / loss =    0.344, correct =    89.03%
# epoch = 20 -> eval  / loss =     1.71, correct =    60.32%
# 21.4294
#
# epoch = 21 -> train / loss =    0.314, correct =    89.81%
# epoch = 21 -> eval  / loss =     1.75, correct =    59.93%
# 21.4912
#
# epoch = 22 -> train / loss =    0.289, correct =    90.64%
# epoch = 22 -> eval  / loss =      1.7, correct =    60.72%
# 21.5977
#
# epoch = 23 -> train / loss =    0.256, correct =    91.79%
# epoch = 23 -> eval  / loss =     1.79, correct =    60.82%
# 21.4459
#
# epoch = 24 -> train / loss =    0.241, correct =    92.34%
# epoch = 24 -> eval  / loss =     1.78, correct =     61.6%
# 21.3295
#
# epoch = 25 -> train / loss =    0.224, correct =    92.72%
# epoch = 25 -> eval  / loss =     1.81, correct =     61.3%
# 21.6027
#
# epoch = 26 -> train / loss =    0.197, correct =    93.83%
# epoch = 26 -> eval  / loss =     1.82, correct =    61.12%
# 21.3772
#
# epoch = 27 -> train / loss =    0.184, correct =    94.14%
# epoch = 27 -> eval  / loss =     1.86, correct =    61.36%
# 21.4499
#
# epoch = 28 -> train / loss =     0.17, correct =    94.52%
# epoch = 28 -> eval  / loss =     1.91, correct =    60.88%
# 21.3891
#
# epoch = 29 -> train / loss =    0.164, correct =    94.81%
# epoch = 29 -> eval  / loss =     1.83, correct =     61.3%
# 21.5027
#
# epoch = 30 -> train / loss =    0.154, correct =    95.16%
# epoch = 30 -> eval  / loss =     1.87, correct =    61.51%
# 21.5886
#
# epoch = 31 -> train / loss =    0.139, correct =    95.56%
# epoch = 31 -> eval  / loss =     1.89, correct =    61.51%
# 21.4184
#
# epoch = 32 -> train / loss =     0.13, correct =    95.82%
# epoch = 32 -> eval  / loss =     1.92, correct =    61.16%
# 21.5072
#
# epoch = 33 -> train / loss =    0.123, correct =    96.15%
# epoch = 33 -> eval  / loss =     1.95, correct =    61.36%
# 21.7987
#
# epoch = 34 -> train / loss =    0.122, correct =    96.07%
# epoch = 34 -> eval  / loss =     1.97, correct =    61.38%
# 21.5984
#
# epoch = 35 -> train / loss =    0.116, correct =    96.43%
# epoch = 35 -> eval  / loss =     1.99, correct =    61.31%
# 21.4153
#
# epoch = 36 -> train / loss =    0.111, correct =     96.5%
# epoch = 36 -> eval  / loss =     1.94, correct =    61.84%
# 21.5096
#
# epoch = 37 -> train / loss =      0.1, correct =    96.96%
# epoch = 37 -> eval  / loss =     1.95, correct =    61.22%
# 21.5631
#
# epoch = 38 -> train / loss =   0.0961, correct =    96.93%
# epoch = 38 -> eval  / loss =      2.0, correct =    61.99%
# 21.4203
#
# epoch = 39 -> train / loss =   0.0874, correct =    97.33%
# epoch = 39 -> eval  / loss =     1.99, correct =    61.69%
# 21.5538
#
# epoch = 40 -> train / loss =   0.0847, correct =    97.41%
# epoch = 40 -> eval  / loss =      2.0, correct =    61.59%
# 21.5715
#
# epoch = 41 -> train / loss =   0.0765, correct =    97.63%
# epoch = 41 -> eval  / loss =     2.09, correct =    61.61%
# 21.5278
#
# epoch = 42 -> train / loss =   0.0819, correct =    97.45%
# epoch = 42 -> eval  / loss =     2.02, correct =    61.68%
# 21.5978
#
# epoch = 43 -> train / loss =   0.0767, correct =    97.68%
# epoch = 43 -> eval  / loss =     2.07, correct =    61.12%
# 21.6414
#
# epoch = 44 -> train / loss =   0.0719, correct =    97.76%
# epoch = 44 -> eval  / loss =     2.09, correct =    61.63%
# 21.8293
#
# epoch = 45 -> train / loss =   0.0747, correct =    97.63%
# epoch = 45 -> eval  / loss =     2.09, correct =    61.72%
# 21.5515
#
# epoch = 46 -> train / loss =   0.0702, correct =    97.83%
# epoch = 46 -> eval  / loss =     2.06, correct =    61.96%
# 21.6672
#
# epoch = 47 -> train / loss =    0.067, correct =    97.92%
# epoch = 47 -> eval  / loss =     2.14, correct =    61.69%
# 21.7887
#
# epoch = 48 -> train / loss =   0.0692, correct =    97.78%
# epoch = 48 -> eval  / loss =     2.05, correct =    61.58%
# 21.8317
#
# epoch = 49 -> train / loss =   0.0629, correct =    98.08%
# epoch = 49 -> eval  / loss =     2.14, correct =    61.79%
# 21.4838
